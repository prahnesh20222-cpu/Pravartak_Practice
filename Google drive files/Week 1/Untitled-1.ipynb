# %%
a =1

# %%
b =a

# %%
print (a,b)
# Out:
# 1 1

# %%
b=2
print(a,b)
# Out:
# 1 2

# %%
print("hello","\nworld")
# Out:
# hello
# world

# %%
for i in range(1,10,2):
    print(f"Hello {i}")
    i = i+3
    print(i)
print("loop ended")
# Out:
# Hello 1
# 4
# Hello 3
# 6
# Hello 5
# 8
# Hello 7
# 10
# Hello 9
# 12
# loop ended
