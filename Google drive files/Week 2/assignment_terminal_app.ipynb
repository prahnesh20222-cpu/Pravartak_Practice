# %% [markdown]
# # Interactive Student Registry Terminal Application
#
# This notebook contains the Capstone Project assignment. You will implement a complete, interactive student registry terminal application in Python.
#
# ### Objectives:
# By completing this project, you will demonstrate your understanding of:
# - **Classes & Objects**: Defining attributes, constructors (`__init__`), and instance methods.
# - **Data Structures**: Lists and Dictionaries (storing student profiles and grades).
# - **Control Flow**: Loops (`while` and `for`), conditionals (`if-elif-else`), and control keywords (`pass`, `continue`, `break`).
# - **Operators**: Arithmetic (`+`, `/`), Relational (`>=`, `<`, `==`), and Logical (`and`, `or`).
# - **Input/Output**: Using `input()` to receive user choices and `print()` to display menus and profiles.
#
# ### Instructions:
# 1. Read the requirements in the assignment description below.
# 2. Write your implementation inside the blank code cell.
# 3. Run the code cell and interact with the menu to verify your output matches the **Expected Output Flow**.

# %% [markdown]
# ---
# ## Topic 7: Interactive Student Registry Terminal Application
# This project pulls together classes, objects, lists, dictionaries, loops, relational and logical operators, conditionals, custom functions, input parsing, and control keywords (`pass`, `continue`, `break`).

# %% [markdown]
# ### Question 1: Implement the Student Registry Console Application
# Implement the full system code for the interactive terminal application. The application must:
# - Contain a `Student` class that stores a name, age, and a dictionary of grades (`self.grades`).
# - Contain registry management logic wrapping lists of students, matching checks, calculating class averages, and formatting reports.
# - Provide a menu loop (`while True`) with input option handling (1-6) using if-elif-else statements, containing `break` to exit, `continue` to refresh, and a stub method leveraging `pass`.

# %%
# Write the complete terminal application code here

# %% [markdown]
# #### **Expected Output Flow (Interactive Run with Evaluations & Stubs):**
# ```text
# ==============================
#    STUDENT REGISTRY SYSTEM
# ==============================
# 1. Add Student
# 2. Add Grades to a Student
# 3. View Student Profile
# 4. List All Students
# 5. Run Statistics (Placeholder)
# 6. Exit
# Enter your choice (1-6): 1
#
# --- Add New Student ---
# Enter student name: John Doe
# Enter student age: 16
# Student 'John Doe' added successfully!
#
# ==============================
#    STUDENT REGISTRY SYSTEM
# ==============================
# 1. Add Student
# 2. Add Grades to a Student
# 3. View Student Profile
# 4. List All Students
# 5. Run Statistics (Placeholder)
# 6. Exit
# Enter your choice (1-6): 1
#
# --- Add New Student ---
# Enter student name: Jane Smith
# Enter student age: 18
# Student 'Jane Smith' added successfully!
#
# ==============================
#    STUDENT REGISTRY SYSTEM
# ==============================
# 1. Add Student
# 2. Add Grades to a Student
# 3. View Student Profile
# 4. List All Students
# 5. Run Statistics (Placeholder)
# 6. Exit
# Enter your choice (1-6): 2
#
# --- Add Grades ---
# Enter the name of the student to add grades for: John Doe
# Enter subject name (or type 'done' to finish): Math
# Enter grade for Math (0-100): 150
# Grade must be between 0 and 100.
# Enter subject name (or type 'done' to finish): Math
# Enter grade for Math (0-100): 95
# Added grade 95.0 for Math.
# Enter subject name (or type 'done' to finish): English
# Enter grade for English (0-100): 88
# Added grade 88.0 for English.
# Enter subject name (or type 'done' to finish): done
#
# ==============================
#    STUDENT REGISTRY SYSTEM
# ==============================
# 1. Add Student
# 2. Add Grades to a Student
# 3. View Student Profile
# 4. List All Students
# 5. Run Statistics (Placeholder)
# 6. Exit
# Enter your choice (1-6): 4
#
# --- Registry List ---
# 1. John Doe (Age: 16, Average: 91.50)
# 2. Jane Smith (Age: 18, Average: 0.00)
#
# ==============================
#    STUDENT REGISTRY SYSTEM
# ==============================
# 1. Add Student
# 2. Add Grades to a Student
# 3. View Student Profile
# 4. List All Students
# 5. Run Statistics (Placeholder)
# 6. Exit
# Enter your choice (1-6): 5
# Running statistics... (Method stubbed with 'pass')
#
# ==============================
#    STUDENT REGISTRY SYSTEM
# ==============================
# 1. Add Student
# 2. Add Grades to a Student
# 3. View Student Profile
# 4. List All Students
# 5. Run Statistics (Placeholder)
# 6. Exit
# Enter your choice (1-6): 6
# Exiting system. Goodbye!
# ```
