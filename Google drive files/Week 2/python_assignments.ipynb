# %% [markdown]
# # Python Programming Assignments: Print Functions & Variables
#
# Welcome to your first Python programming assignment! This notebook contains a series of exercises to practice using Python's `print()` function, f-strings, advanced printing parameters (`sep` and `end`), and variables.
#
# ### Instructions:
# 1. Read the question in the markdown cells.
# 2. Write your solution in the blank code cell below the question.
# 3. Compare your output with the **Expected Output** shown directly below the answer cell.

# %% [markdown]
# ---
# ## Topic 1: Printing Multiple Items
# You can pass multiple arguments to the `print()` function, separated by commas. Python will print them separated by a single space by default.

# %% [markdown]
# ### Question 1
# Write a single print statement that prints your first name, last name, and age as separate items.

# %%
# Write your code here

# %% [markdown]
# #### **Expected Output:**
# ```text
# Alice Smith 25
# ```
# *(Note: You can use your own name and age, or the example names/age above)*

# %% [markdown]
# ---
# ## Topic 2: Using f-strings (Formatted String Literals)
# f-strings provide a clean and concise way to embed expressions inside string literals using curly braces `{}`. To create an f-string, prefix the string with `f` or `F` before the opening quotation mark.

# %% [markdown]
# ### Question 2
# Define a variable `city` with value `"Paris"` and a variable `country` with value `"France"`.
# Use an f-string to print: `"Paris is the capital of France."`

# %%
# Write your code here

# %% [markdown]
# #### **Expected Output:**
# ```text
# Paris is the capital of France.
# ```

# %% [markdown]
# ---
# ## Topic 3: Advanced Parameters: `sep` and `end`
# - The `sep` parameter controls the separator character printed between multiple items (default is space).
# - The `end` parameter controls what is printed at the end of the print statement (default is a newline `\n`).

# %% [markdown]
# ### Question 3.1: Using `sep`
# Print three colors: `"Red"`, `"Green"`, and `"Blue"` in a single print statement, separated by a hyphen and spaces (` - `).

# %%
# Write your code here

# %% [markdown]
# #### **Expected Output:**
# ```text
# Red - Green - Blue
# ```

# %% [markdown]
# ### Question 3.2: Using `end`
# Write two separate print statements. The first should print `"Loading"` and end with three dots `"..."` instead of a newline. The second print statement should print `"Complete!"` on the same line.

# %%
# Write your code here

# %% [markdown]
# #### **Expected Output:**
# ```text
# Loading...Complete!
# ```

# %% [markdown]
# ---
# ## Topic 4: Variables & Assignments (Comprehensive Exercise)
# Let's put everything together!

# %% [markdown]
# ### Question 4
# 1. Define a variable `item` and assign it the value `"Laptop"`.
# 2. Define a variable `price` and assign it the value `1200`.
# 3. Define a variable `quantity` and assign it the value `3`.
# 4. Calculate the total cost (price multiplied by quantity) and store it in a variable called `total`.
# 5. Use an f-string to construct two output strings:
#    - One displaying the item details: `"Item: Laptop, Qty: 3"`
#    - One displaying the price details: `"Price: $1200, Total: $3600"`
# 6. Print both of these strings in a single print command, using `" | "` as the separator (`sep`), and ending the print statement with a exclamation mark (`!`).

# %%
# Write your code here

# %% [markdown]
# #### **Expected Output:**
# ```text
# Item: Laptop, Qty: 3 | Price: $1200, Total: $3600!
# ```

# %% [markdown]
# ---
# ## Topic 5: Getting User Input using `input()`
# In Python, we get input from the user using the `input()` function.
# - `input(prompt)` displays the prompt string and returns the user's input as a **string**.
# - To read numbers, we must convert the string using type casting, like `int()` or `float()`.

# %% [markdown]
# ### Question 5.1: Reading a String
# Use `input()` to prompt the user with `"Enter your favorite programming language: "`. Store the response in a variable `language` and then print it.

# %%
# Write your code here

# %% [markdown]
# #### **Expected Output:**
# ```text
# Enter your favorite programming language: Python
# Your favorite language is Python!
# ```
# *(Note: The actual output depends on what you type in the prompt)*

# %% [markdown]
# ### Question 5.2: Reading and Casting Numbers
# Prompt the user to enter two integers. Convert them to `int`, add them together, and print the result using an f-string.
# - Prompt 1: `"Enter first number: "`
# - Prompt 2: `"Enter second number: "`

# %%
# Write your code here

# %% [markdown]
# #### **Expected Output:**
# ```text
# Enter first number: 10
# Enter second number: 20
# The sum of 10 and 20 is 30.
# ```

# %% [markdown]
# ---
# ## Topic 6: Operators (Arithmetic, Comparison, and Logical)
# Operators are special symbols in Python that carry out arithmetic or logical computation.
# - **Arithmetic Operators:** Perform mathematical operations (`+`, `-`, `*`, `/`, `%`, `**`, `//`).
# - **Comparison (Conditional) Operators:** Compare values and return `True` or `False` (`==`, `!=`, `>`, `<`, `>=`, `<=`).
# - **Logical Operators:** Combine conditional statements (`and`, `or`, `not`).

# %% [markdown]
# ### Question 6.1: Arithmetic Operators
# Prompt the user to enter two numbers. Print the results of adding, subtracting, multiplying, and dividing the first number by the second.

# %%
# Write your code here

# %% [markdown]
# #### **Expected Output:**
# ```text
# Enter first number: 8
# Enter second number: 2
# Addition: 10.0
# Subtraction: 6.0
# Multiplication: 16.0
# Division: 4.0
# ```

# %% [markdown]
# ### Question 6.2: Comparison (Conditional) Operators
# Write a program that prompts the user to enter their age. Compare the age to see if they are eligible to vote (18 or older). Print `True` or `False` directly from the comparison expression.

# %%
# Write your code here

# %% [markdown]
# #### **Expected Output:**
# ```text
# Enter your age: 20
# Eligible to vote: True
# ```

# %% [markdown]
# ### Question 6.3: Logical Operators
# Prompt the user to enter a number. Check if the number is greater than 0 **and** even. Print the boolean result.

# %%
# Write your code here

# %% [markdown]
# #### **Expected Output:**
# ```text
# Enter a number: 6
# Is positive and even: True
# ```

# %% [markdown]
# ---
# ## Topic 7: Conditional Statements (`if`, `if-else`, `if-elif-else`)
# Conditional statements allow you to run different blocks of code based on certain conditions.
# - `if condition:` executes code only if the condition evaluates to `True`.
# - `else:` runs if all preceding conditions evaluate to `False`.
# - `elif condition:` (short for else if) checks another condition if the previous ones were `False`.

# %% [markdown]
# ### Question 7.1: Simple `if` Statement
# Write a program that takes an integer input from the user. If the number is greater than 100, print `"That is a large number!"`.

# %%
# Write your code here

# %% [markdown]
# #### **Expected Output (if input is 150):**
# ```text
# Enter a number: 150
# That is a large number!
# ```

# %% [markdown]
# ### Question 7.2: `if-else` Statement
# Write a program that takes an integer input. Check if the number is even or odd.
# - If it is even, print `"The number is even."`
# - Otherwise, print `"The number is odd."`

# %%
# Write your code here

# %% [markdown]
# #### **Expected Output:**
# ```text
# Enter an integer: 7
# The number is odd.
# ```

# %% [markdown]
# ### Question 7.3: `if-elif-else` Statement
# Write a program that prompts the user for their score (0-100) and prints a letter grade based on the score:
# - 90 and above: `"Grade: A"`
# - 80 to 89: `"Grade: B"`
# - 70 to 79: `"Grade: C"`
# - Below 70: `"Grade: F"`

# %%
# Write your code here

# %% [markdown]
# #### **Expected Output:**
# ```text
# Enter your score: 85
# Grade: B
# ```

# %% [markdown]
# ### Question 7.4: Another `if-elif-else` Statement (Ticket Pricing)
# Write a program that prompts the user to enter their age. Based on the age, print the price of a movie ticket:
# - Under 5 years old: `"Ticket Price: Free"`
# - 5 to 17 years old: `"Ticket Price: $10"`
# - 18 to 64 years old: `"Ticket Price: $20"`
# - 65 years old and older: `"Ticket Price: $15"`

# %%
# Write your code here

# %% [markdown]
# #### **Expected Output:**
# ```text
# Enter your age: 34
# Ticket Price: $20
# ```

# %% [markdown]
# ---
# ## Topic 8: Loops (`for` and `while` loops)
# Loops are used to repeat a block of code multiple times.
# - A `for` loop is typically used when you want to iterate over a sequence (like a range of numbers).
# - Nested loops (loops inside loops) are useful for working with multi-dimensional patterns.

# %% [markdown]
# ### Question 8.1: Multiplication Table
# Write a program that prompts the user to enter a number, and then prints the multiplication table for that number from 1 to 10.

# %%
# Write your code here

# %% [markdown]
# #### **Expected Output:**
# ```text
# Enter a number for the multiplication table: 5
# 5 x 1 = 5
# 5 x 2 = 10
# 5 x 3 = 15
# 5 x 4 = 20
# 5 x 5 = 25
# 5 x 6 = 30
# 5 x 7 = 35
# 5 x 8 = 40
# 5 x 9 = 45
# 5 x 10 = 50
# ```

# %% [markdown]
# ### Question 8.2: Simple Pyramid Pattern (Right-Angled Triangle)
# Write a program that prompts the user for a height (number of rows) and prints a simple right-angled triangle pattern of asterisks (`*`).

# %%
# Write your code here

# %% [markdown]
# #### **Expected Output:**
# ```text
# Enter the height of the pattern: 4
# *
# **
# ***
# ****
# ```

# %% [markdown]
# ### Question 8.3: Complicated Pyramid Pattern (Centered Triangle)
# Write a program that prompts the user for a height and prints a centered pyramid pattern of asterisks (`*`).
# *(Hint: You will need to calculate and print the correct number of leading spaces before the stars on each row)*

# %%
# Write your code here

# %% [markdown]
# #### **Expected Output:**
# ```text
# Enter the height of the pyramid: 4
#    *
#   ***
#  *****
# *******
# ```

# %% [markdown]
# ### Question 8.4: Interactive Calculator using `while` loop
# Write a program that continuously prompts the user to perform arithmetic operations until they choose to exit.
# - Inside a `while` loop, ask the user to enter an operation: `+`, `-`, `*`, `/` or `q` to quit.
# - If the user enters `q`, print a goodbye message and terminate the loop using `break`.
# - If they enter a valid operator, prompt them to enter two numbers (convert them to float).
# - Perform the calculation and print the result.
# - If they enter an invalid operator, print an error message and let the loop continue.

# %%
# Write your code here

# %% [markdown]
# #### **Expected Output:**
# ```text
# Enter operator (+, -, *, /, or 'q' to quit): +
# Enter first number: 12
# Enter second number: 8
# Result: 20.0
#
# Enter operator (+, -, *, /, or 'q' to quit): *
# Enter first number: 5
# Enter second number: 6
# Result: 30.0
#
# Enter operator (+, -, *, /, or 'q' to quit): invalid
# Invalid operator! Please try again.
#
# Enter operator (+, -, *, /, or 'q' to quit): q
# Goodbye!
# ```

# %% [markdown]
# ---
# ## Topic 9: Loop Control Statements (`break`, `continue`, `pass`)
# Loop control statements change the normal execution flow of a loop:
# - `break` terminates the loop statement immediately and transfers execution to the statement following the loop.
# - `continue` skips the remaining statements in the current iteration of the loop and moves directly to the next iteration.
# - `pass` is a null statement; it is used as a placeholder when a statement is syntactically required but you do not want to execute any code.

# %% [markdown]
# ### Question 9.1: Using `break`
# Write a program that uses a `for` loop to iterate from numbers 1 to 10. Print each number, but stop (break) the loop when the number reaches 5.

# %%
# Write your code here

# %% [markdown]
# #### **Expected Output:**
# ```text
# 1
# 2
# 3
# 4
# 5
# Loop ended.
# ```

# %% [markdown]
# ### Question 9.2: Using `continue`
# Write a program that uses a `for` loop to iterate from numbers 1 to 10. Print each number, but skip (continue) printing the number if it is even, so only odd numbers are printed.

# %%
# Write your code here

# %% [markdown]
# #### **Expected Output:**
# ```text
# 1
# 3
# 5
# 7
# 9
# ```

# %% [markdown]
# ### Question 9.3: Using `pass`
# Write a `for` loop iterating from numbers 1 to 5. If the number is 3, use the `pass` statement as a placeholder. Otherwise, print the number.

# %%
# Write your code here

# %% [markdown]
# #### **Expected Output:**
# ```text
# 1
# 2
# 4
# 5
# ```

# %% [markdown]
# ---
# ## Topic 10: Functions
# Functions are reusable blocks of code that perform a specific task.
# - Define a function using the `def` keyword.
# - Use `return` to send a value back to the caller.
# - Functions can have positional parameters, keyword arguments, and default argument values.

# %% [markdown]
# ### Question 10.1: Simple Function with Parameter
# Define a function called `greet` that takes one parameter `name` and prints `"Hello, [name]!"` where `[name]` is replaced by the argument passed. Call the function with `"Alice"`.

# %%
# Write your code here

# %% [markdown]
# #### **Expected Output:**
# ```text
# Hello, Alice!
# ```

# %% [markdown]
# ### Question 10.2: Function with a Return Value
# Define a function called `square` that takes a number as a parameter and returns its squared value. Call the function with `5` and print the result.

# %%
# Write your code here

# %% [markdown]
# #### **Expected Output:**
# ```text
# 25
# ```

# %% [markdown]
# ### Question 10.3: Function with Multiple Parameters and Default Arguments
# Define a function called `power` that takes two parameters: `base` and `exponent`. Give `exponent` a default value of `2`. The function should return `base` raised to the power of `exponent`.
# - Call `power(3)` (should square it using the default value) and print the result.
# - Call `power(2, 3)` (should calculate 2 raised to 3) and print the result.

# %%
# Write your code here

# %% [markdown]
# #### **Expected Output:**
# ```text
# 9
# 8
# ```

# %% [markdown]
# ---
# ## Topic 11: Libraries (Import and Usage)
# Libraries allow you to extend Python's functionality by importing pre-written modules.
# - Use the `import module_name` syntax to import a library.
# - Use `import module_name as alias` to give the module a shorter name.
# - Use `from module_name import specific_function` to import only a specific part of a library.

# %% [markdown]
# ### Question 11.1: Standard Import (`math` library)
# Import the Python standard `math` library. Use `math.sqrt()` to calculate the square root of `16` and print it.

# %%
# Write your code here

# %% [markdown]
# #### **Expected Output:**
# ```text
# 4.0
# ```

# %% [markdown]
# ### Question 11.2: Specific Item Import and Aliasing
# 1. Import the `randint` function from the `random` library directly.
# 2. Import the `time` library as `t`.
# 3. Print a random integer between `1` and `10` (inclusive) using `randint`.
# 4. Use `t.ctime()` to print the current local date and time.

# %%
# Write your code here

# %% [markdown]
# #### **Expected Output:**
# ```text
# Random number: 7
# Current date/time: Thu Jul 16 10:31:00 2026
# ```
# *(Note: The actual values will depend on when you run it and the random choice)*
